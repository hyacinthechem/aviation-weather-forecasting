# %%
import numpy as np
import pandas as pd

apt_data = pd.read_csv("NZWN.csv")
apt_data.head()
# Out:
# /var/folders/mw/sxfcbx2d059gnq4bg5rfkzl40000gn/T/ipykernel_79541/1357269379.py:4: DtypeWarning: Columns (2,3,4,5,6,8,10,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   apt_data = pd.read_csv("NZWN.csv")
#   station             valid   tmpf   dwpf   relh   drct  sknt  p01i   alti  \
# 0    NZWN  2020-01-01 00:00  66.20  57.20  72.74   10.0  23.0   0.0  29.97
# 1    NZWN  2020-01-01 00:30  68.00  57.20  68.35  360.0  28.0   0.0  29.94
# 2    NZWN  2020-01-01 01:00  68.00  57.20  68.35   10.0  26.0   0.0  29.94
# 3    NZWN  2020-01-01 01:30  68.00  59.00  72.92   10.0  24.0   0.0  29.94
# 4    NZWN  2020-01-01 02:00  68.00  59.00  72.92   10.0  26.0   0.0  29.94
#
#   mslp  ... wxcodes ice_accretion_1hr ice_accretion_3hr ice_accretion_6hr  \
# 0    M  ...       M                 M                 M                 M
# 1    M  ...       M                 M                 M                 M
# ...

# %%
apt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104462 entries, 0 to 104461
# Data columns (total 30 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   station            104462 non-null  object
#  1   valid              104462 non-null  object
#  2   tmpf               104462 non-null  object
#  3   dwpf               104462 non-null  object
#  4   relh               104462 non-null  object
#  5   drct               104462 non-null  object
#  6   sknt               104462 non-null  object
#  7   p01i               104462 non-null  float64
#  8   alti               104462 non-null  object
#  9   mslp               104462 non-null  object
#  10  vsby               104462 non-null  object
#  11  gust               104462 non-null  object
#  12  skyc1              104462 non-null  object
#  13  skyc2              104462 non-null  object
#  14  skyc3              104462 non-null  object
# ...
